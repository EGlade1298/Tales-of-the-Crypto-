# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi.newsapi_client import NewsApiClient

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Eric\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv('C:/Users/Eric/Desktop/api keys/.env')
api_key = os.getenv("NEWS_API_KEY")

print(api_key)
# Out:
# 68bdc7d1be514ed686d48465a25527e7

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_news_en = newsapi.get_everything(q='bitcoin', language='en', sort_by='relevancy',)

bitcoin_news_en["totalResults"]
# Out:
# 7692

# %%
# Fetch the Ethereum news articles
ethereum_news_en = newsapi.get_everything(q='ethereum', language='en', sort_by='relevancy',)

ethereum_news_en["totalResults"]
# Out:
# 4885

# %%
# Create the Bitcoin sentiment scores DataFrame
def get_sentiment_score(article, based_on):
    sentiments = []
    for article in article["articles"]:
        try:
            text = article[based_on]
            date = article["publishedAt"]
            sentiment = analyzer.polarity_scores(text)
            compound = sentiment["compound"]
            pos = sentiment["pos"]
            neu = sentiment["neu"]
            neg = sentiment["neg"]
            sentiments.append({
                based_on : text,
                "Compound": compound,
                "Negative": neg,
                "Neutral": neu,
                "Positive": po
            })
        except AttributeError:
            pass
    # Create DataFrame
    df = pd.DataFrame(sentiments)
    return df

btc_sentiment_df = get_sentiment_score(bitcoin_news_en, 'content')
btc_sentiment_df
# Out:
#                                               content  Compound  Negative  \
# 0   It was 8:45 in the morning of June 13 when Bil...    0.5574     0.000
# 1   Tools to trace cryptocurrencies have, over jus...    0.0000     0.000
# 2   You gotta hand it to some people for being imp...    0.5994     0.034
# 3   Cryptocurrencies are often criticized for bein...   -0.5584     0.170
# 4   Elon Musk-owned electric vehicle making compan...    0.2023     0.000
# ..                                                ...       ...       ...
# 95  Tiffany Fong, a retail investor in crypto, has...   -0.6124     0.184
# 96  Hi again Jordan Parker Erb here. Insider caugh...    0.0000     0.000
# 97  US stocks dipped Monday ahead of a packed week...    0.4215     0.000
# 98  Solana was the latest target of hackers early ...   -0.1531     0.045
# 99  US stocks rose Wednesday, looking to trim rece...   -0.1027     0.079
#
#     Neutral  Positive
# 0     0.881     0.119
# 1     1.000     0.000
# ...

# %%
# Create the Ethereum sentiment scores DataFrame
all_dates = []
def get_sentiment_score(article, based_on):
    sentiments = []
    for article in article["articles"]:
        try:
            text = article[based_on]
            date = article["publishedAt"]
            sentiment = analyzer.polarity_scores(text)
            compound = sentiment["compound"]
            pos = sentiment["pos"]
            neu = sentiment["neu"]
            neg = sentiment["neg"]
            all_dates.append(date)
            sentiments.append({
                based_on : text,
                "Compound": compound,
                "Negative": neg,
                "Neutral": neu,
                "Positive": pos
            })
        except AttributeError:
            pass
    # Create DataFrame
    df = pd.DataFrame(sentiments, all_dates)
    return df

eth_sentiment_df = get_sentiment_score(ethereum_news_en, 'content')
eth_sentiment_df
# Out:
#                                                                 content  \
# 2022-08-18T16:09:33Z  Cryptocurrencies are often criticized for bein...
# 2022-08-04T15:40:58Z  The non-fungible token\r\n (NFT) market has fa...
# 2022-08-02T17:57:18Z  It's a day of the week ending in the letter "y...
# 2022-07-23T18:19:10Z  Less than two weeks into its soft launch, Game...
# 2022-07-25T04:06:00Z  The Ethereum Merge is significant, and not jus...
# ...                                                                 ...
# 2022-07-22T19:21:28Z  What happened\r\nCryptocurrency Ethereum Class...
# 2022-08-17T14:12:25Z  The downturn in the crypto market might end up...
# 2022-07-28T18:30:07Z  What happened\r\nIn the latest bullish turn in...
# 2022-08-04T11:00:00Z  After a long crypto winter, the price of Ether...
# 2022-08-16T10:00:00Z  One of the most important events in crypto his...
#
#                       Compound  Negative  Neutral  Positive
# ...

# %%
# Describe the Bitcoin Sentiment
btc_sentiment_df.describe()
# Out:
#          Compound    Negative    Neutral    Positive
# count  100.000000  100.000000  100.00000  100.000000
# mean     0.047564    0.053250    0.88068    0.066060
# std      0.452871    0.073677    0.09109    0.070961
# min     -0.908100    0.000000    0.62800    0.000000
# 25%     -0.296000    0.000000    0.82225    0.000000
# 50%      0.000000    0.000000    0.88500    0.058000
# 75%      0.362050    0.102250    0.95250    0.105250
# max      0.924600    0.307000    1.00000    0.372000

# %%
# Describe the Ethereum Sentiment
eth_sentiment_df.describe()
# Out:
#          Compound    Negative     Neutral    Positive
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.120887    0.045190    0.882500    0.072330
# std      0.452613    0.068611    0.085959    0.069513
# min     -0.936600    0.000000    0.646000    0.000000
# 25%     -0.115675    0.000000    0.820000    0.000000
# 50%      0.051350    0.000000    0.888500    0.061000
# 75%      0.510600    0.059000    0.943750    0.119500
# max      0.840200    0.354000    1.000000    0.249000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
nltk.download('stopwords')

# Expand the default stopwords list if necessary
sw = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Eric\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub(' ', text)
    
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    words = word_tokenize(re_clean)
    words = word_tokenize(re_clean.lower())
    
    # Lemmatize words into root words
    tokens = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    words = [word for word in words if word not in sw]
    
    # Remove the stop words
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
btc_sentiment_df["tokens"] = btc_sentiment_df["content"].apply(tokenizer)
btc_sentiment_df.head(5)
# Out:
#                                              content  Compound  Negative  \
# 0  It was 8:45 in the morning of June 13 when Bil...    0.5574     0.000
# 1  Tools to trace cryptocurrencies have, over jus...    0.0000     0.000
# 2  You gotta hand it to some people for being imp...    0.5994     0.034
# 3  Cryptocurrencies are often criticized for bein...   -0.5584     0.170
# 4  Elon Musk-owned electric vehicle making compan...    0.2023     0.000
#
#    Neutral  Positive                                             tokens
# 0    0.881     0.119  [it, wa, in, the, morning, of, june, when, bil...
# 1    1.000     0.000  [tool, to, trace, cryptocurrencies, have, over...
# 2    0.835     0.130  [you, got, ta, hand, it, to, some, people, for...
# 3    0.763     0.068  [cryptocurrencies, are, often, criticized, for...
# 4    0.947     0.053  [elon, musk, owned, electric, vehicle, making,...

# %%
# Create a new tokens column for Ethereum
eth_sentiment_df["tokens"] = eth_sentiment_df["content"].apply(tokenizer)
eth_sentiment_df.head(5)
# Out:
#                                                                 content  \
# 2022-08-18T16:09:33Z  Cryptocurrencies are often criticized for bein...
# 2022-08-04T15:40:58Z  The non-fungible token\r\n (NFT) market has fa...
# 2022-08-02T17:57:18Z  It's a day of the week ending in the letter "y...
# 2022-07-23T18:19:10Z  Less than two weeks into its soft launch, Game...
# 2022-07-25T04:06:00Z  The Ethereum Merge is significant, and not jus...
#
#                       Compound  Negative  Neutral  Positive  \
# 2022-08-18T16:09:33Z   -0.5584     0.170    0.763     0.068
# 2022-08-04T15:40:58Z   -0.0217     0.051    0.901     0.048
# 2022-08-02T17:57:18Z   -0.2732     0.115    0.827     0.059
# 2022-07-23T18:19:10Z   -0.1531     0.045    0.955     0.000
# 2022-07-25T04:06:00Z    0.2023     0.000    0.952     0.048
#
#                                                                  tokens
# 2022-08-18T16:09:33Z  [cryptocurrencies, are, often, criticized, for...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
btc_text = btc_sentiment_df["content"].str.cat()
clean_btc_text =  tokenizer(btc_text)
bigram_counts = Counter(ngrams(clean_btc_text, n=2))
bigram_counts.most_common(20)
# Out:
# [(('in', 'the'), 21),
#  (('of', 'the'), 17),
#  (('aug', 'reuters'), 16),
#  (('july', 'reuters'), 12),
#  (('it', 'bitcoin'), 10),
#  (('the', 'world'), 9),
#  (('for', 'the'), 8),
#  (('to', 'the'), 8),
#  (('of', 'it'), 8),
#  (('in', 'a'), 8),
#  (('second', 'quarter'), 8),
#  (('the', 'crypto'), 8),
#  (('the', 'year'), 7),
#  (('hard', 'drive'), 6),
#  (('elon', 'musk'), 6),
#  (('the', 'company'), 6),
#  (('char', 'july'), 6),
#  (('the', 'second'), 6),
#  (('char', 'aug'), 6),
#  (('more', 'than'), 6)]

# %%
# Generate the Ethereum N-grams where N=2
eth_text = eth_sentiment_df["content"].str.cat()
clean_eth_text =  tokenizer(eth_text)
bigram_counts = Counter(ngrams(clean_eth_text, n=2))
bigram_counts.most_common(20)
# Out:
# [(('char', 'the'), 17),
#  (('in', 'the'), 17),
#  (('of', 'the'), 16),
#  (('on', 'the'), 11),
#  (('the', 'crypto'), 10),
#  (('to', 'the'), 9),
#  (('the', 'ethereum'), 9),
#  (('the', 'most'), 7),
#  (('ethereum', 'eth'), 7),
#  (('it', 's'), 6),
#  (('in', 'a'), 6),
#  (('from', 'the'), 6),
#  (('to', 'be'), 6),
#  (('m', 'char'), 6),
#  (('to', 'a'), 6),
#  (('char', 'what'), 6),
#  (('what', 'happened'), 6),
#  (('the', 'cryptocurrency'), 5),
#  (('aug', 'reuters'), 5),
#  (('over', 'the'), 5)]

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
token_count(clean_btc_text, N=10)
# Out:
# [('the', 170),
#  ('a', 148),
#  ('char', 99),
#  ('to', 90),
#  ('of', 86),
#  ('in', 77),
#  ('bitcoin', 59),
#  ('it', 58),
#  ('s', 37),
#  ('on', 37)]

# %%
# Use token_count to get the top 10 words for Ethereum
token_count(clean_eth_text, N=10)
# Out:
# [('the', 189),
#  ('a', 120),
#  ('char', 97),
#  ('to', 88),
#  ('of', 72),
#  ('in', 60),
#  ('and', 57),
#  ('is', 48),
#  ('on', 45),
#  ('it', 43)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
big_string_1 = ' '.join(clean_btc_text)
wc = WordCloud().generate(big_string_1)
plt.title("Bitcoin Word Cloud", fontsize=40, loc="center", fontweight="bold")
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
big_string_2 = ' '.join(clean_eth_text)
wc = WordCloud().generate(big_string_2)
plt.title("Ethereum Word Cloud", fontsize=40, loc="center", fontweight="bold")
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
btc_text = (big_string_1)

# %%
# Run the NER processor on all of the text
doc_1 = nlp(btc_text)

# Add a title to the document
doc_1.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(doc_1, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">it wa in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  of june when
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bill stewart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  the ceo of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %%
# List all Entities
for ent in doc_1.ents:
    print(ent.text, ent.label_)
# Out:
# the morning TIME
# bill stewart PERSON
# maine GPE
# bitcoin GPE
# one CARDINAL
# the last several year DATE
# every year DATE
# belgium GPE
# the university of cambridge bitcoin electricity ORG
# wednesday DATE
# bitcoin GPE
# the world biggest technology company ORG
# week DATE
# bitcoin GPE
# million CARDINAL
# the second quarter DATE
# first ORDINAL
# august DATE
# this week DATE
# bitcoin GPE
# a good month DATE
# bitcoin GPE
# a while after month DATE
# july DATE
# october DATE
# reuters ORG
# friday DATE
# bitcoin GPE
# three week DATE
# july DATE
# bitcoin PERSON
# saturday DATE
# the year DATE
# wednesday DATE
# second quarter DATE
# a record billion MONEY
# first ORDINAL
# reuters blackrock inc blk ORG
# the united state GPE
# new york GPE
# bitcoin PERSON
# wednesday DATE
# tesla inc tsla ORG
# fiat ORG
# ten CARDINAL
# wednesday DATE
# july DATE
# reuters ORG
# slushie NORP
# bitcoin valley LOC
# santa lucia GPE
# one CARDINAL
# today DATE
# quantify GPE
# bitcoin GPE
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_text = (big_string_2)

# %%
# Run the NER processor on all of the text
doc_2 = nlp(eth_text)

# Add a title to the document
doc_2.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(doc_2, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">cryptocurrencies are often criticized for being bad for the planet
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     every year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  bitcoin mining consumes more energy than
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     belgium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  according to
# ...

# %%
# List all Entities
for ent in doc_2.ents:
    print(ent.text, ent.label_)
# Out:
# every year DATE
# belgium GPE
# the university of cambridge bitcoin electricity ORG
# app ORG
# a day of the week ending DATE
# the security and exchange commission ORG
# peopl char PERSON
# le than two week DATE
# one CARDINAL
# second ORDINAL
# vitalik buterin PERSON
# thursday DATE
# paris GPE
# reuters crypto exchange zipmex ORG
# bitcoin GPE
# this week DATE
# monday DATE
# vivaldi PERSON
# jon von tetzchner PERSON
# the last month DATE
# bitcoin GPE
# second ORDINAL
# the u treasury department s office of foreign asset ORG
# monday DATE
# crypto platform tornado ORG
# north korean NORP
# bitcoin GPE
# monday DATE
# mid june DATE
# europe LOC
# one CARDINAL
# million of pound overnight QUANTITY
# november DATE
# joe hovde PERSON
# new york GPE
# july DATE
# bitcoin PERSON
# saturday DATE
# the year DATE
# july DATE
# bitcoin PERSON
# wednesday DATE
# next month DATE
# london GPE
# reuters ORG
# july DATE
# monthly DATE
# cryptocompare PERSON
# thursday DATE
# pri ORG
# ...

# %% [markdown]
# ---
